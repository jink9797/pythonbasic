# %%
import numpy as np
import pandas as pd

# %%
np.arange(2,21,3)
# Out:
# array([ 2,  5,  8, 11, 14, 17, 20])

# %%
index = [ _ for _ in range(1, 4) ]
data = ['일', '이', '삼' ]
pd.Series(data,index)
# Out:
# 1    일
# 2    이
# 3    삼
# dtype: object

# %% [markdown]
#  DataFrame merge()

# %% [markdown]
# 테이블에 키 값이 같은 데이터가 여러개 있는 경우에는 있을 수 있는 모든 경우의
# 수를 따져서 조합을 만들어냄

# %%
dat1 = pd.DataFrame({
    '품종': ['setosa','setosa','virginica','virginica'],
    '꽃잎길이' : [1.4, 1.3, 1.5, 1.3]},
    columns = ['품종','꽃잎길이'])
dat1
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
dat2 = pd.DataFrame({
    '품종' : ['setosa','virginica','virginica','versicolor'],
    '꽃잎너비' : [0.4, 0.3, 0.5, 0.3]},
    columns = ['품종','꽃잎너비'])
dat2
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
pd.merge(dat1,dat2)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %% [markdown]
# ### DataFrame 시계열 자료 다루기 DatetimeIndex
# - 시계열 자료는 인덱스가 날짜 혹은 시간인 데이터를 말함
# - 시계열 자료를 생성하려면 인덱스를 DatetimeIndex 자료형으로 만들어야함
# - DatetimeIndex는 특정한 순간에 기록된
# - ------> 타임스탬프(timestamp) 형식의 시계열 자료를 다루기 위한 인덱스
# - 타임스탬프 인덱스의 label값이 반드시 일정한 간격일 필요는 없다
#
# 1. DatetimeIndex 인덱스는 다음과 같은 보조 함수를 사용하여 생성
# 2. pd.to_datetime 함수
# 3. pd.date_range 함

# %% [markdown]
# pd.to_datetime 함수를 쓰면 날짜/시간을 나타내는 문자열을 자동으로 datetime
# 자료형으로 바꾼 후 DatetimeIndex 자료형 인덱스를 생성

# %%
date_str = ['2018, 1, 1','2018, 1, 4','2018, 1, 5','2018, 1, 6']
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-04', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
np.random.seed(0)
s = pd.Series(np.random.randn(4), index = indx)
s

# %% [markdown]
# pd.date_range 함수를 쓰면 모든 날짜/시간을 일일이 입력할 필요없이 시작일과 종료일
# 또는 시작일과 기간을 입력하면 범위 내의 인덱스를 생성

# %%
pd.date_range('2018-4-1','2018-4-30')
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2018-4-1',periods = 30)
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# B는 평일

# %% [markdown]
# - s: 초
# - T: 분
# - H: 시간
# - D: 일(day)
# - B: 주말이 아닌 평일
# - W: 주(일요일)
# - W-MON: 주(월요일)
# - M: 각 달(month)의 마지막 날
# - MS: 각 달의 첫날
# - BM: 주말이 아닌 평일 중에서 각 달의 마지막 날
# - BMS: 주말이 아닌 평일 중에서 각 달의 첫날
# - WOM-2THU: 각 달의 두번째 목요일
# - Q-JAN: 각 분기의 첫달의 마지막 날
# - Q-DEC: 각 분기의 마지막 달의 마지막 날

# %%
pd.date_range('2018-4-1','2018-4-30',freq = 'B')
# Out:
# DatetimeIndex(['2018-04-02', '2018-04-03', '2018-04-04', '2018-04-05',
#                '2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11',
#                '2018-04-12', '2018-04-13', '2018-04-16', '2018-04-17',
#                '2018-04-18', '2018-04-19', '2018-04-20', '2018-04-23',
#                '2018-04-24', '2018-04-25', '2018-04-26', '2018-04-27',
#                '2018-04-30'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# W는 일요일

# %%
pd.date_range('2018-1-1','2018-12-31',freq = 'W')
# Out:
# DatetimeIndex(['2018-01-07', '2018-01-14', '2018-01-21', '2018-01-28',
#                '2018-02-04', '2018-02-11', '2018-02-18', '2018-02-25',
#                '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25',
#                '2018-04-01', '2018-04-08', '2018-04-15', '2018-04-22',
#                '2018-04-29', '2018-05-06', '2018-05-13', '2018-05-20',
#                '2018-05-27', '2018-06-03', '2018-06-10', '2018-06-17',
#                '2018-06-24', '2018-07-01', '2018-07-08', '2018-07-15',
#                '2018-07-22', '2018-07-29', '2018-08-05', '2018-08-12',
#                '2018-08-19', '2018-08-26', '2018-09-02', '2018-09-09',
#                '2018-09-16', '2018-09-23', '2018-09-30', '2018-10-07',
#                '2018-10-14', '2018-10-21', '2018-10-28', '2018-11-04',
#                '2018-11-11', '2018-11-18', '2018-11-25', '2018-12-02',
#                '2018-12-09', '2018-12-16', '2018-12-23', '2018-12-30'],
# ...

# %% [markdown]
# M: 각 달(month)의 마지막 날
# MS: 각 달의 첫날
# BMS: 주말이 아닌 평일 중에서 각 달의
# 첫날

# %%
pd.date_range('2018-1-1','2018-12-31',freq = 'W-MON')
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22',
#                '2018-01-29', '2018-02-05', '2018-02-12', '2018-02-19',
#                '2018-02-26', '2018-03-05', '2018-03-12', '2018-03-19',
#                '2018-03-26', '2018-04-02', '2018-04-09', '2018-04-16',
#                '2018-04-23', '2018-04-30', '2018-05-07', '2018-05-14',
#                '2018-05-21', '2018-05-28', '2018-06-04', '2018-06-11',
#                '2018-06-18', '2018-06-25', '2018-07-02', '2018-07-09',
#                '2018-07-16', '2018-07-23', '2018-07-30', '2018-08-06',
#                '2018-08-13', '2018-08-20', '2018-08-27', '2018-09-03',
#                '2018-09-10', '2018-09-17', '2018-09-24', '2018-10-01',
#                '2018-10-08', '2018-10-15', '2018-10-22', '2018-10-29',
#                '2018-11-05', '2018-11-12', '2018-11-19', '2018-11-26',
#                '2018-12-03', '2018-12-10', '2018-12-17', '2018-12-24',
#                '2018-12-31'],
# ...

# %%
pd.date_range('2018-4-1','2018-12-31',freq = 'MS')
# Out:
# DatetimeIndex(['2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range('2018-4-1','2018-12-31',freq = 'BMS')
# Out:
# DatetimeIndex(['2018-04-02', '2018-05-01', '2018-06-01', '2018-07-02',
#                '2018-08-01', '2018-09-03', '2018-10-01', '2018-11-01',
#                '2018-12-03'],
#               dtype='datetime64[ns]', freq='BMS')

# %% [markdown]
# - 시계열 데이터의 인덱스는 시간이나 날짜를 나타내기 때문에 날짜 이동 등의 다양한
# 연산이 가능
# - shift 연산을 사용하면 인덱스는 그대로 두고 데이터만 이동

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(4), index=pd.date_range(
    '2018-1-1',periods =4,freq='M'))
ts
# Out:
# 2018-01-31    1.764052
# 2018-02-28    0.400157
# 2018-03-31    0.978738
# 2018-04-30    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(1)
# Out:
# 2018-01-31         NaN
# 2018-02-28    1.764052
# 2018-03-31    0.400157
# 2018-04-30    0.978738
# Freq: M, dtype: float64

# %%
ts.shift(-1)
# Out:
# 2018-01-31    0.400157
# 2018-02-28    0.978738
# 2018-03-31    2.240893
# 2018-04-30         NaN
# Freq: M, dtype: float64

# %%
ts.shift(1,freq='M')
# Out:
# 2018-02-28    1.764052
# 2018-03-31    0.400157
# 2018-04-30    0.978738
# 2018-05-31    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(1,freq = 'W')
# Out:
# 2018-02-04    1.764052
# 2018-03-04    0.400157
# 2018-04-01    0.978738
# 2018-05-06    2.240893
# dtype: float64

# %% [markdown]
# - datetime 자료형 Series에는 dt 접근자가 있어 datetime 자료형이 가진 몇가지 유용한 속성과 메서드를 사용가능
# - year, month, day, weekday 등의 속성을 이용하면 년, 월, 일, 요일 정보알 수 있음

# %%
s = pd.Series(pd.date_range('2020-12-25',periods = 100, freq ='D'))
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %%
s.dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
#       ...
# 95    2021
# 96    2021
# 97    2021
# 98    2021
# 99    2021
# Length: 100, dtype: int64

# %%
s.dt.weekday
# Out:
# 0     4
# 1     5
# 2     6
# 3     0
# 4     1
#      ..
# 95    1
# 96    2
# 97    3
# 98    4
# 99    5
# Length: 100, dtype: int64

# %% [markdown]
# strftime 메서드를 이용하여 문자열을 만드는 것도 가능

# %%
s.dt.strftime('%Y년 %m월 %d일')
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object

# %%
np.random.seed(0)
df2 = pd.DataFrame({
    'key1': ['A', 'A', 'B', 'B', 'A'],
    'key2': ['one', 'two', 'one', 'two', 'one'],
    'data1': [1, 2, 3, 4, 5],
    'data2': [10, 20, 30, 40, 50]
})
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
groups = df2.groupby(df2.key1)
groups

# %%
groups.sum() # a그룹과 b그룹 데이터의 합을 구하기 위해 sum그룹연산 사용
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %% [markdown]
# GroupBy 클래스 객체를 명시적(groups라는 변수)으로 얻을 필요가 없다면
# groupby 메서드와 그룹연산 메서드를 연속으로 호출

# %%
df2.data1.groupby(df2.key1).sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %% [markdown]
# 데이터를 그룹으로 나눈

# %%
df2.groupby(df2.key1)['data1'].sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2.groupby(df2.key1).sum()['data1']
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2.data1.groupby([df2.key1, df2.key2]).sum()
# Out:
# key1  key2
# A     one     6
#       two     2
# B     one     3
#       two     4
# Name: data1, dtype: int64

# %% [markdown]
# 그룹 분석 기능을 사용하면 인구 데이터로부터 지역별 합계를 구할 수 있다

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
df1['인구'].groupby([df1['지역'],df1['연도']]).sum().unstack('연도')
# Out:
# 연도      2005     2010      2015
# 지역
# 경상권  3512547  3393191   3448737
# 수도권  9762546  9894685  12794763

# %% [markdown]
# 다음 데이터는 150송이의 붓꽃(iris)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['alive'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
def change_boolean(value):
    if value == 'yes':
        return True
    else:
        return False

# %%
titanic['alive'] = titanic['alive'].apply(change_boolean)

# %%
titanic['alive']
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: alive, Length: 891, dtype: bool

# %% [markdown]
# ### Matplotlib
# - 차트나 플롯으로 시각화하는 패키지(그래프를 그리는 것이 목적)
# 1. line plot
# 2. scatter plot
# 3. contour plot
# 4. surface plot
# 5. bar chart
# 6. histogram
# 7. boxplot

# %% [markdown]
# #### matplotlib.pyplot 임포트하기
# - import matplotlib as mpl
# - import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #### 만약 그래프가 출력되지 않는다면

# %%
# %matplotlib inline

# %% [markdown]
# #### matplotlib.pyplot.plot()
# - plot() 자주씀

# %% [markdown]
# - x 축의 위치를 x틱(tick)이라고 함
# - default는 0 ~ N-1 범위의 index array

# %% [markdown]
# ### 라인플롯(line plot) - x축의 위치(tick)

# %% [markdown]
# - title() 플롯의 제목을 의미
# - show()는 플롯을 그림으로 표시
# 1) non-interactive모드

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %% [markdown]
# #### 한글 폰트 사용하기 ####
#
# - title() 인수로 한글 문자열 전달하면 잘 전달이 안됨(한글 필요하면 폰트를 다운받아야함)
# - ------>> http://noonnu.cc/ : 무료 폰트 사이트
# - 리눅스에서 네이버에 제공하는 나눔글꼴 설치방법(Colab 도 사용가능)
# - ------>> !sudo apt install -y fonts-nanum*
# - ------>> !sudo fc-cache -fv
# - ------>> !rm ~/.cache/matplotlib -rf

# %%
# import matplotlib.font_manager

# matplotlib.font_manager._rebuild()
# sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts()
font_list
# Out:
# ['C:\\Windows\\Fonts\\GILI____.TTF',
#  'C:\\Windows\\Fonts\\PER_____.TTF',
#  'C:\\WINDOWS\\Fonts\\BRADHITC.TTF',
#  'C:\\WINDOWS\\Fonts\\DUBAI-BOLD.TTF',
#  'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\WINDOWS\\Fonts\\corbel.ttf',
#  'C:\\WINDOWS\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\Windows\\Fonts\\H2PORM.TTF',
#  'C:\\WINDOWS\\Fonts\\FORTE.TTF',
#  'C:\\WINDOWS\\Fonts\\gulim.ttc',
#  'C:\\WINDOWS\\Fonts\\TCMI____.TTF',
#  'C:\\WINDOWS\\Fonts\\VINERITC.TTF',
#  'C:\\WINDOWS\\Fonts\\H2MKPB.TTF',
#  'C:\\Windows\\Fonts\\LCALLIG.TTF',
#  'C:\\Windows\\Fonts\\PERBI___.TTF',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\WINDOWS\\Fonts\\BOD_CB.TTF',
#  'C:\\WINDOWS\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\WINDOWS\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\GARAIT.TTF',
# ...

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
[matplotlib.font_manager.FontProperties(fname=font).get_name() for font in font_list if 'Nanum' in font]
# Out:
# ['NanumGothic']

# %%
# mpl.rc('font',family='NanumGothic.ttc')      ###전체범위에 대한 폰트

# %%
mpl.rcParams['font.family']='NanumGothic.ttf'  ###전체범위에 대한 폰트

# %% [markdown]
# ### Unicode minus 표기법 설정
# - 음수 부호를 유니코드와 ASCII중 어떤 문자로 표기할지 설정하는 것
# - rc()메서드로 RcParams 중 axes.unicode_minus의 값을 False로 변경하면 ASCII의 문자로 표현

# %%
mpl.rcParams['axes.unicode_minus'] = False    ### 아스키코드로

# %%
plt.title('안녕')
plt.plot([1,4,9,16])
plt.show()

# %%
global_font = {'family':'NanumGothic', 'size':12,'weight':'bold'}

#폰트설정
mpl.rc('font',**global_font) #pass in the font dict as kwargs
# mpl.rc('font, family':'NanumGothic', 'size':12,'weight':'bold'} 와 같이 동작

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40,],[1,4,9,16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %%
font1 = {'family': 'NanumGothic', 'size': 24, 
         'color':  'black'}
font2 = {'family': 'NanumGothic', 'size': 18, 'weight': 'bold',
         'color':  'darkred'}
font3 = {'family': 'NanumGothic', 'size': 12, 'weight': 'light',
         'color':  'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict=font1)
plt.xlabel('엑스 축', fontdict=font2)
plt.ylabel('와이 축', fontdict=font3)
plt.show()

# %% [markdown]
# ### Style 설정하기

# %%
plt.title('default 스타일의 plot')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16],'rp--')
plt.show()

# %% [markdown]
# - 스타일 문자열은 색상, 마커, 선 종류의 순서로 지정(일부 생략 시 디폴트값 적용)
# - 색상을 지정하는 방법은 색이름, 약자, # 문자로 시작되는 RGB코드 사용
# https://matplotlib.org/2.0.2/examples/color/named_colors.html

# %% [markdown]
# #### marker
# - 데이터 위치를 나타내는 기호를 마커라고 함
# -https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers

# %% [markdown]
# #### line
# - https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %% [markdown]
# ##### 기타 style 도있다

# %%
plt.plot([10,20,30,40],[1,4,9,16],c='b',
         lw = 5, ls='--',marker='o',ms=15,mec='g',mew=5,mfc='r')
plt.title('스타일 적용 예')
plt.show()

# %% [markdown]
# - 플롯 그림을 보면 몇몇 점들은 그림의 범위 경계선에 있어서 잘 보이지 않는 경우가 있다
# - 그림의 범위를 수동으로 지정하려면 xlim 명령과 ylim 명령을 사용
# - 그림의 범위가 되는 x축, y축의 최소값과 최대값을 지정

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# - 플롯이나 차트에서 축상의 위치 표시 지점을 틱(tick)이라 함
# - 틱에 써진 숫자 혹은 글자를 틱 라벨(tick label)이라고 한다
# - 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks 명령이나 yticks 명령을 사용

# %%
X = np.linspace(-np.pi, np.pi, 256)         # -np.pi 부터 np.pi 사이의 256개를 구함 
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()                                                    # 코사인을 구함

# %% [markdown]
# ### 틱 설정하기
# - 틱 라벨 문자열에는 $$ 사이에 수학 문자식을 넣을 수있다
# https://matplotlib.org/3.1.1/tutorials/text/mathtext.html

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("LaTeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %% [markdown]
# ### 여러개의 선 그리기
# - 라인 플롯에서 선을 하나가 아니라 여러개를 그리고 싶은 경우
# - ---------------> x 데이터, y 데이터, 스타일 문자열을 반복하여 인수로 넘긴다
# - 이 경우에는 하나의 선을 그릴 때 처럼 x 데이터나 스타일 문자열을 생략할 수 없다

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %% [markdown]
# - 하나의 plot 명령이 아니라 복수의 plot 명령을 하나의 그림에 겹쳐서 그릴 수도 있다

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
# plt.hold(True)   # <- 1,5 버전에서는 이 코드가 필요하다.
plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
# plt.hold(False)  # <- 1,5 버전에서는 이 코드가 필요하다.
plt.show()

# %% [markdown]
# ### 범례
# - 여러개의 라인 플롯을 동시에 그리는 경우
# - ----> 각 선이 무슨 자료를 표시하는지를 보여주기 위해 legend 명령으로 범례(legend)를 추가할 수 있다
# - 범례의 위치는 자동으로 정해지지만 수동으로 설정하고 싶으면 loc 인수를 사용

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")    # legend label을 설정
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)        # upper left
plt.show()

# %% [markdown]
# ### x축, y축 라벨, 타이틀
# - 플롯의 x축 위치와 y축 위치에는 데이터가 의미하는 바를 표시하기 위해 라벨(label)를 추가할 수 있다
# - 라벨을 붙이려면 xlabel. ylabel 명령을 사용한다
# - 플롯의 위에는 title 명령으로 제목(title)을 붙일 수 있다

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
plt.title("섭씨 온도와 화씨 온도")
plt.plot([30,50,70,90,100],[0,10,20,30,35],'r-.')
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.show()

# %%
x = np.arange(32,100)
y = (x-32)*5/9
plt.title("섭씨 온도와 화씨 온도")
plt.plot(x,y,'r-.')
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.show()

# %% [markdown]
# ### Figure
# - Matplotlib는 data를 Figure(e.g. windows, Jupyter widgets, etc.)에 x-y좌표의 그래프로 표시(3차원은 x-y-z,극 좌표는 세타-r)
# - 각각의 Figure는 하나 이상의 Axes를 가짐
# - pyplot.subplots()를 사용하는 것
# - Axes.plot()를 활용

# %%
fig, ax = plt.subplots()               # Create a figure containing a single axes.
ax.plot([1,2,3,4],[1,4,2,3]);          # Plot some data on the axes.

# %% [markdown]
# - 전체 그림(그래프)을 의미하는 객체
# - Figure 객체는 Axes, 특수 Artist그룹(title, figure legends, colorbar, etc), 그리고 중첩된 subfigures까지 포함 가능

# %%
# fig = plt.figure() # 잘 안씀   # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2,2) # a figure with a 2x2 grid of Axes     #axs= shape이 2x2로 나뉘어져 있음

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# 현재 사용하고 있는 figure 객체를 얻으려면( 다른 변수에 할당 가능)  gcf()메서드 사용

# %%
f1 = plt.figure(1)
plt.title('현재의 figure객체')
plt.plot([1,2,3,4],'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 1226074715424
# Figure(640x480) 1226074715424

# %% [markdown]
# ### Axes

# %%
ax1 = plt.subplot(2,1,1)
# 여기에서 윗부분에 그릴 플롯 명령 실행
ax2 = plt.subplot(2,1,2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행
